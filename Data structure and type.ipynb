# %% [markdown]
# 1. Write a code to create a string with your name and print it ?

# %%
name='Iqbal Hossain'
name
# Out:
# 'Iqbal Hossain'

# %% [markdown]
# 2. Write a code to find the length of the string "Hello World"?

# %%
st="Hello World"
len(st)
# Out:
# 11

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming"?

# %%
chr="Python Programming"
chr[:3]
# Out:
# 'Pyt'

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase ?

# %%
text='hello'
text
# Out:
# 'hello'

# %%
text.upper()
# Out:
# 'HELLO'

# %% [markdown]
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"?

# %%
fruit="I like apple"
fruit
# Out:
# 'I like apple'

# %%
fruit.replace('apple','orange')
# Out:
# 'I like orange'

# %% [markdown]
# 6. Write a code to create a list with numbers 1 to 5 and print it ?

# %%
list1=[1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4] ?

# %%
list1=[1,2,3,4]
list1
# Out:
# [1, 2, 3, 4]

# %%
list1.append(10)
list1
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5] ?

# %%
list2=[1,2,3,4,5]
list2
# Out:
# [1, 2, 3, 4, 5]

# %%
list2.remove(3)
list2
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'] ?

# %%
list_3=['a','b','c','d']
list_3
# Out:
# ['a', 'b', 'c', 'd']

# %%
list_3[1]
# Out:
# 'b'

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
my_list=[10,20,30,40,50]
my_list
# Out:
# [10, 20, 30, 40, 50]

# %%
my_list.reverse()
my_list
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.

# %%
tup=(100,200,300)
tup
# Out:
# (100, 200, 300)

# %% [markdown]
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
color=('red','green','blue','yellow')
color
# Out:
# ('red', 'green', 'blue', 'yellow')

# %%
color[1:]
# Out:
# ('green', 'blue', 'yellow')

# %% [markdown]
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).

# %%
numbers=(10,20,5,15)
numbers
# Out:
# (10, 20, 5, 15)

# %%
min(numbers)
# Out:
# 5

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
pet=('dog','cat','rabbit')
pet
# Out:
# ('dog', 'cat', 'rabbit')

# %%
pet.index('cat')
# Out:
# 1

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
fruit_1=('orange','mango','guava')
fruit_1
# Out:
# ('orange', 'mango', 'guava')

# %%
'kiwi'in fruit_1
# Out:
# False

# %% [markdown]
# That means kiwi is not present in fruit_1

# %%
fruit_2=('watermelon','kiwi','apple')
fruit_2
# Out:
# ('watermelon', 'kiwi', 'apple')

# %%
'kiwi' in fruit_2
# Out:
# True

# %% [markdown]
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

# %%
set_1={1,2,3}
set_1
# Out:
# {1, 2, 3}

# %% [markdown]
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

# %%
set_2={1,2,3,4,5}
set_2
# Out:
# {1, 2, 3, 4, 5}

# %%
set_2.clear()
set_2
# Out:
# set()

# %% [markdown]
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
my_numbers={1,2,3,4}
my_numbers
# Out:
# {1, 2, 3, 4}

# %%
my_numbers.remove(4)
my_numbers
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

# %%
num1={1,2,3}
num2={3,4,5}
num1.union(num2)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

# %%
set1={1,2,3}
set2={2,3,4}
set1.intersection(set2)
# Out:
# {2, 3}

# %% [markdown]
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
dic_1={"name":"Iqbal Hossain","age":23,"city":"Kolkata"}
dic_1
# Out:
# {'name': 'Iqbal Hossain', 'age': 23, 'city': 'Kolkata'}

# %% [markdown]
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

# %%
person = {'name': 'John', 'age': 25}
person
# Out:
# {'name': 'John', 'age': 25}

# %%
person['country'] = 'USA'
person
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

# %%
person = {'name': 'Alice', 'age': 30}
person
# Out:
# {'name': 'Alice', 'age': 30}

# %%
person['name']
# Out:
# 'Alice'

# %% [markdown]
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

# %%
person={'name': 'Bob', 'age': 22, 'city': 'New York'}
person
# Out:
# {'name': 'Bob', 'age': 22, 'city': 'New York'}

# %%
del person['age']
person
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-181926158.py in <cell line: 0>()
# ----> 1 del person['age']
#       2 person
#
# KeyError: 'age'

# %% [markdown]
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

# %%
person={'name': 'Alice', 'city': 'Paris'}
'city' in person        #---> if exist it prints true
# Out:
# True

# %%
'class' in person      #---> if does not exists then it prints false
# Out:
# False

# %% [markdown]
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

# %%
lst=[1,2,3,4]
tup=(1,2,3,4)
dic={'name':'Iqbal','set':{1,2,3},'Education':'Graduate'}
# Out:
# {'name': 'Iqbal', 'set': {1, 2, 3}, 'Education': 'Graduate'}

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
dic
# Out:
# {'name': 'Iqbal', 'set': {1, 2, 3}, 'Education': 'Graduate'}

# %%
tup
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)

# %%
import random
num = [random.randint(1, 100) for _ in range(5)]
num
# Out:
# [14, 86, 35, 18, 39]

# %%
num.sort()
num
# Out:
# [14, 18, 35, 39, 86]

# %% [markdown]
# 28. Write a code to create a list with strings and print the element at the third index.

# %%
fruits = ["apple", "banana", "cherry", "orange", "mango"]
fruits[3]
# Out:
# 'orange'

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.

# %%
dict1={'a':1,'b':2}
dict2={'c':3,'d':4}
dict1.update(dict2)
dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# 30. Write a code to convert a list of strings into a set.

# %%
fruits = ["apple", "banana", "cherry", "apple", "banana"]
unique_fruits=set(fruits)
unique_fruits
# Out:
# {'apple', 'banana', 'cherry'}
